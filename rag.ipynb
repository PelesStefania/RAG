# %%
! pip install langchain_community tiktoken langchain-google-genai langchainhub chromadb langchain pypdf
# Out:
# Requirement already satisfied: langchain_community in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (0.4.1)
# Requirement already satisfied: tiktoken in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (0.12.0)
# Requirement already satisfied: langchain-google-genai in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (4.2.0)
# Requirement already satisfied: langchainhub in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (0.1.21)
# Requirement already satisfied: chromadb in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (1.5.0)
# Requirement already satisfied: langchain in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (1.2.10)
# Requirement already satisfied: pypdf in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (6.7.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from langchain_community) (1.2.10)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from langchain_community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from langchain_community) (2.0.46)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from langchain_community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from langchain_community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from langchain_community) (3.13.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from langchain_community) (9.1.4)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from langchain_community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from langchain_community) (0.7.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from langchain_community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from langchain_community) (2.4.2)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from tiktoken) (2026.1.15)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.56.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from langchain-google-genai) (1.62.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from langchain-google-genai) (2.12.5)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from langchainhub) (24.2)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from langchainhub) (2.32.4.20260107)
# Requirement already satisfied: build>=1.0.3 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from chromadb) (1.4.0)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.40.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from chromadb) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from chromadb) (1.24.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from chromadb) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from chromadb) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from chromadb) (1.78.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from chromadb) (0.21.1)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from chromadb) (3.11.7)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from chromadb) (14.3.2)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.8 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from langchain) (1.0.8)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.22.0)
# Requirement already satisfied: pyproject_hooks in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (0.9.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (4.12.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.47.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2.48.0)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (15.0.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: certifi in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from httpx>=0.27.0->chromadb) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from httpx>=0.27.0->chromadb) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.6.3)
# Requirement already satisfied: durationpy>=0.7 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (1.1.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (1.33)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (0.14.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.7 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (1.0.7)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (0.3.5)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (3.6.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: flatbuffers in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.5)
# Requirement already satisfied: sympy in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.1 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-proto==1.39.1 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.60b1)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: greenlet>=1 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain_community) (3.3.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from tokenizers>=0.13.2->chromadb) (1.4.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (46.0.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (4.9.1)
# Requirement already satisfied: filelock in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.2.0)
# Requirement already satisfied: typer-slim in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (0.21.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain_community) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.8->langchain) (1.12.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community) (1.1.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.6.2)
# Requirement already satisfied: pycparser in c:\users\teod4\onedrive\desktop\aiprojects\rag\.venv\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (3.0)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import PyPDFLoader
from langchain_google_genai import GoogleGenerativeAIEmbeddings
import chromadb
from langchain_community.vectorstores import Chroma
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from rpm_limiter import RPMLimiter, call_with_retry
import os

# %%
loader = PyPDFLoader("R2vitamin.pdf")
docs = loader.load()

print(len(docs))
# Out:
# 33

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)

chunks = splitter.split_documents(docs)
print("Total chunks:", len(chunks))

for i, ch in enumerate(chunks[:3], start=1):
    print(f"\n==================== CHUNK {i} ====================")
    print(ch.page_content)
# Out:
# Total chunks: 107
#
# ==================== CHUNK 1 ====================
# Sethi et al, Int. J. Sci. Info. 2024, 1 (10), 23-55
#
# 23
#
# INTERNATIONAL JOURNAL OF SCIENTIFIC INFORMATION
# www.jsiinternational.com                                   ISSN: 2583-8512
#                                          Review Article
# A Comprehensive Guide to Benefits and Production of Vitamins
# Neeraj Sethi1, Deepika Gulati2, Sushila Kaura 3*
# 1Department of Biotechnology, OSGU, Hisar, Haryana
# 2Department of Botany, Government College, Hisar
# 3Department of Pharmacology, OSGU, Hisar, Haryana
#
# 20neerajsethi@gmail.com
# deepikahau84@gmail.com
# sushilakaura@gmail.com
#
# *Corresponding Author: sushilakaura@gmail.com
# Article Received on: 26/12/23 Revised on: 3/1/24 Approved for publication: 10/1/24
# ABSTRACT
# Vitamins are essential organic compounds that play crucial roles in various physiological processes, ensuring the
# proper functioning and maintenance of the human body. These micronutrients are vital for growth, development,
#
# ==================== CHUNK 2 ====================
# proper functioning and maintenance of the human body. These micronutrients are vital for growth, development,
# and overall health. Classified into water -soluble (e.g., vitamin C and B -complex vitamins) and fat -soluble (e.g.,
# vitamins A, D, E, and K) catego ries, each vitamin serves specific functions. The body cannot produce most
# vitamins, necessitating their intake through a well-balanced diet or supplements. Deficiencies in vitamins can lead
# to various health issues, emphasizing the importance of maintaini ng adequate levels to support optimal bodily
# functions. While the majority of vitamins are obtained through a well -balanced diet, advancements in
# biotechnology and industrial processes have allowed for the production of synthetic vitamins. For instance, water-
# soluble vitamins like vitamin C are often produced through fermentation using microorganisms like bacteria or
#
# ==================== CHUNK 3 ====================
# soluble vitamins like vitamin C are often produced through fermentation using microorganisms like bacteria or
# yeast. Fat -soluble vitamins, on the other hand, may be synthesized through chemical processes. Additionally,
# advancements in genetic engineering have facilitated the development of genetically modified organisms that can
# produce specific vitamins, contributing to the production of fortified foods. As the demand for vitamins continues
# to grow, ongoing research focuses on sustainable and efficient methods of production, ensuring a stable supply to
# address nutritional needs on a global scale.
#  Keywords: Ascorbic acid, Biotin, Fermentation, Tocopherol, Industrial production, Vitamins
# INTRODUCTION
# Vitamins are indispensable for the
# maintenance of g ood health, as they
# participate in a myriad of physiological
# processes that contribute to the proper
# functioning of the body  (Ames, 2018) .
# Water-soluble vitamins, including vitamin

# %%
PERSIST_DIR ="./chroma_db"

os.makedirs(PERSIST_DIR, exist_ok=True)

embeddings = GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-001")

client = chromadb.PersistentClient(path=PERSIST_DIR)

vectorstore = Chroma(
    client=client,
    collection_name="course_rag",
    embedding_function=embeddings,
)

limiter = RPMLimiter(max_rpm=80)  

batch_size = 60
for i in range(0, len(chunks), batch_size):
    batch = chunks[i:i + batch_size]
    call_with_retry(vectorstore.add_documents, batch, limiter=limiter)

retriever = vectorstore.as_retriever(search_kwargs={"k": 2})

# %%
prompt = ChatPromptTemplate.from_template(
    "You are an assistant for question-answering tasks. "
    "Use the following pieces of retrieved context to answer the question. "
    "If you don't know the answer, just say that you don't know. "
    "Use three sentences maximum and keep the answer concise.\n\n"
    "Question: {question}\n"
    "Context: {context}\n"
    "Answer:"
)

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)

def format_docs(docs):
    return "\n\n".join(d.page_content for d in docs)

rag_chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

rag_chain.invoke("What are fat-soluble vitamins and what do they do?")
# Out:
# "Fat-soluble vitamins include A, D, E, and K, which are absorbed with dietary fats and stored in the body's fatty tissues. They are vital for various functions such as vision, immune function, skin health, calcium absorption, bone health, and blood clotting. Vitamin E also acts as a powerful antioxidant, protecting cells from oxidative damage."
